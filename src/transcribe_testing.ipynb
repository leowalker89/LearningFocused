# %%
import assemblyai as aai
import os
from pathlib import Path
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Check for API key
if not os.getenv("ASSEMBLYAI_API_KEY"):
    print("Error: ASSEMBLYAI_API_KEY not found in environment variables.")
    print("Please create a .env file with your API key.")

# %%
import json
from datetime import datetime
import os
from pathlib import Path

# Select the file to transcribe
audio_file_path = "../podcast_downloads/S2E282 The SAT Isn’t About Intelligence… Here’s How to Win (Part 1).mp3"
output_dir = "../transcripts"

if not Path(audio_file_path).exists():
    print(f"File not found: {audio_file_path}")
else:
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    print(f"Transcribing: {audio_file_path}")

    # Configure transcription with speaker labels
    config = aai.TranscriptionConfig(speaker_labels=True)
    transcriber = aai.Transcriber()

    # Start the transcription
    transcript = transcriber.transcribe(audio_file_path, config=config)

    # Check for errors
    if transcript.status == aai.TranscriptStatus.error:
        print(f"Transcription failed: {transcript.error}")
    else:
        # Build the JSON structure
        json_output = {
            "meta_data": {
                "og_file_name": os.path.basename(audio_file_path),
                "file_path": audio_file_path,
                "date_transcribed": datetime.now().isoformat(),
                "duration_seconds": transcript.audio_duration
            },
            "transcript": []
        }

        # Populate transcript list with converted timestamps
        if transcript.utterances:
            for u in transcript.utterances:
                json_output["transcript"].append({
                    "speaker": u.speaker,
                    "text": u.text,
                    "start_time": u.start / 1000.0, # Convert ms to seconds
                    "end_time": u.end / 1000.0      # Convert ms to seconds
                })
        else:
            json_output["transcript"].append({
                "speaker": None,
                "text": transcript.text,
                "start_time": 0.0,
                "end_time": transcript.audio_duration
            })

        # Define output filename
        base_name = os.path.splitext(os.path.basename(audio_file_path))[0]
        output_path = os.path.join(output_dir, f"{base_name}.json")

        # Save to file
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(json_output, f, indent=2, ensure_ascii=False)
            
        print(f"\n✅ Transcript saved to: {output_path}")
# Out:
# Transcribing: ../podcast_downloads/S2E282 The SAT Isn’t About Intelligence… Here’s How to Win (Part 1).mp3
#
# ✅ Transcript saved to: ../transcripts/S2E282 The SAT Isn’t About Intelligence… Here’s How to Win (Part 1).json

# %%
import pprint

# %%
pprint.pprint(transcript.utterances)
# Out:
# [Utterance(text="We are about to dive into one of the most talked about and sometimes misunderstood parts of the college admissions process. It's the dreaded sat. And joining me today is my special co host, Elle. Elle is a longtime veteran Alpha student. She is going to talk all about our Alpha philosophy when it comes to the SAT and why we think the SAT isn't really about how smart you are. It's not like an IQ test. We're going to explain why and how anyone can can be in the top 10%, not just top students. Top 10%, for your knowledge, is 1350. And that's something that we say at Alpha. We can help deliver our kids. So, Elle, you've got some wild claims about the sat. Let's get into it.", start=640, end=44970, confidence=0.9769843, speaker='A', channel=None, words=[UtteranceWord(text='We', start=640, end=760, confidence=0.9946289, speaker='A', channel=None), UtteranceWord(text='are', start=760, end=960, confidence=0.47192383, speaker='A', channel=None), UtteranceWord(text='about', start=960, end=1200, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='to', start=1200, end=1440, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='dive', start=1440, end=1840, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text='into', start=1840, end=2160, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='one', start=2160, end=2440, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='of', start=2440, end=2560, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='the', start=2560, end=2680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='most', start=2680, end=2920, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='talked', start=2920, end=3280, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='about', start=3280, end=3520, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='and', start=3600, end=4000, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='sometimes', start=4080, end=4600, confidence=0.9998372, speaker='A', channel=None), UtteranceWord(text='misunderstood', start=4600, end=5360, confidence=0.9937337, speaker='A', channel=None), UtteranceWord(text='parts', start=5360, end=5680, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='of', start=5680, end=5760, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='the', start=5760, end=5880, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='college', start=5880, end=6160, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='admissions', start=6160, end=6760, confidence=0.99890137, speaker='A', channel=None), UtteranceWord(text='process.', start=6760, end=7040, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text="It's", start=7120, end=7480, confidence=0.9083659, speaker='A', channel=None), UtteranceWord(text='the', start=7480, end=7680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='dreaded', start=7680, end=8320, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text='sat.', start=8560, end=9440, confidence=0.9921875, speaker='A', channel=None), UtteranceWord(text='And', start=9440, end=9720, confidence=0.9663086, speaker='A', channel=None), UtteranceWord(text='joining', start=9720, end=10080, confidence=0.9996745, speaker='A', channel=None), UtteranceWord(text='me', start=10080, end=10200, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='today', start=10200, end=10440, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='is', start=10440, end=10680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='my', start=10680, end=10880, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='special', start=10880, end=11160, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='co', start=11160, end=11440, ...
#  Utterance(text="Welcome to the Future of Education podcast, hosted by Mackenzie Price. Mackenzie is the founder of a revolutionary new school model that's disrupting education through AI. Join us as we discuss the latest in education innovation.", start=47050, end=60720, confidence=0.9906939, speaker='B', channel=None, words=[UtteranceWord(text='Welcome', start=47050, end=47490, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='to', start=47490, end=47650, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='the', start=47650, end=47850, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='Future', start=47850, end=48130, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='of', start=48130, end=48370, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='Education', start=48370, end=48650, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='podcast,', start=48890, end=49610, confidence=0.9998779, speaker='B', channel=None), UtteranceWord(text='hosted', start=49690, end=50130, confidence=0.9987793, speaker='B', channel=None), UtteranceWord(text='by', start=50130, end=50290, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='Mackenzie', start=50290, end=50850, confidence=0.921875, speaker='B', channel=None), UtteranceWord(text='Price.', start=50850, end=51130, confidence=0.9863281, speaker='B', channel=None), UtteranceWord(text='Mackenzie', start=51530, end=52210, confidence=0.92317706, speaker='B', channel=None), UtteranceWord(text='is', start=52210, end=52370, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='the', start=52370, end=52530, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='founder', start=52530, end=52850, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='of', start=52850, end=53010, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='a', start=53010, end=53170, confidence=0.9980469, speaker='B', channel=None), UtteranceWord(text='revolutionary', start=53170, end=53970, confidence=0.99990237, speaker='B', channel=None), UtteranceWord(text='new', start=53970, end=54290, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='school', start=54290, end=54570, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='model', start=54570, end=54930, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text="that's", start=54930, end=55210, confidence=0.9947917, speaker='B', channel=None), UtteranceWord(text='disrupting', start=55210, end=55730, confidence=0.87386066, speaker='B', channel=None), UtteranceWord(text='education', start=55730, end=56090, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='through', start=56250, end=56570, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='AI.', start=56570, end=57050, confidence=0.9980469, speaker='B', channel=None), UtteranceWord(text='Join', start=57600, end=57800, confidence=0.9987793, speaker='B', channel=None), UtteranceWord(text='us', start=57800, end=57960, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='as', start=57960, end=58120, confidence=0.99853516, speaker='B', channel=None), UtteranceWord(text='we', start=58120, end=58320, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='discuss', start=58320, end=58600, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='the', start=58600, end=58840, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='latest', start=58840, end=59120, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='in', start=59120, end=59480, confidence=0.984375, speaker='B', channel=None), UtteranceWord(text='education', start=59480, end=59840, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='innovation.', start=60080, end=60720, confidence=0.9983724, speaker='B', channel=None)], translated_tex ...
#  Utterance(text="So, first of all, you're a senior.", start=65360, end=66640, confidence=0.99382675, speaker='A', channel=None, words=[UtteranceWord(text='So,', start=65360, end=65640, confidence=0.9794922, speaker='A', channel=None), UtteranceWord(text='first', start=65640, end=65760, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='of', start=65760, end=65840, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='all,', start=65840, end=65960, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text="you're", start=65960, end=66160, confidence=0.99609375, speaker='A', channel=None), UtteranceWord(text='a', start=66160, end=66240, confidence=0.98291016, speaker='A', channel=None), UtteranceWord(text='senior.', start=66240, end=66640, confidence=0.99975586, speaker='A', channel=None)], translated_texts=None),
#  Utterance(text="I'm a senior this year. Yes.", start=66640, end=67920, confidence=0.9297282, speaker='C', channel=None, words=[UtteranceWord(text="I'm", start=66640, end=67040, confidence=0.8769531, speaker='C', channel=None), UtteranceWord(text='a', start=67040, end=67120, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='senior', start=67120, end=67320, confidence=0.88842773, speaker='C', channel=None), UtteranceWord(text='this', start=67320, end=67480, confidence=0.9946289, speaker='C', channel=None), UtteranceWord(text='year.', start=67480, end=67640, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='Yes.', start=67640, end=67920, confidence=0.8198242, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text="So you've been thinking about the SAT for the last year or so. Like, we spend time on it starting junior year and then kind of finish this up, because college application season is right on here. And there are some things that we think at Alpha that are probably a little different. And I'm going to start because, you know, I'm an old lady, I'm going to tell you the story of my sat, the lore of my SAT world.", start=67920, end=89270, confidence=0.96874195, speaker='A', channel=None, words=[UtteranceWord(text='So', start=67920, end=68080, confidence=0.98876953, speaker='A', channel=None), UtteranceWord(text="you've", start=68080, end=68240, confidence=0.9951172, speaker='A', channel=None), UtteranceWord(text='been', start=68240, end=68320, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='thinking', start=68320, end=68520, confidence=0.8391113, speaker='A', channel=None), UtteranceWord(text='about', start=68520, end=68680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='the', start=68680, end=68840, confidence=0.9975586, speaker='A', channel=None), UtteranceWord(text='SAT', start=68840, end=69360, confidence=0.9929199, speaker='A', channel=None), UtteranceWord(text='for', start=69360, end=69640, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='the', start=69640, end=69800, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='last', start=69800, end=70000, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='year', start=70000, end=70240, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='or', start=70240, end=70440, confidence=0.9946289, speaker='A', channel=None), UtteranceWord(text='so.', start=70440, end=70680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='Like,', start=70680, end=70920, confidence=0.8803711, speaker='A', channel=None), UtteranceWord(text='we', start=70920, end=71120, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='spend', start=71120, end=71440, confidence=0.97875977, speaker='A', channel=None), UtteranceWord(text='time', start=71440, end=71680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='on', start=71680, end=71880, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='it', start=71880, end=72080, confidence=0.9921875, speaker='A', channel=None), UtteranceWord(text='starting', start=72080, end=72400, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='junior', start=72400, end=72800, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='year', start=72800, end=73120, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='and', start=73439, end=73720, confidence=0.9946289, speaker='A', channel=None), UtteranceWord(text='then', start=73720, end=73920, confidence=0.9975586, speaker='A', channel=None), UtteranceWord(text='kind', start=73920, end=74120, confidence=0.9682617, speaker='A', channel=None), UtteranceWord(text='of', start=74120, end=74280, confidence=0.97558594, speaker='A', channel=None), UtteranceWord(text='finish', start=74280, end=74560, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='this', start=74560, end=74800, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='up,', start=74800, end=75040, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='because', start=75040, end=75280, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='college', start=75280, end=75640, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='application', start=75640, end=76200, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='season', start=76200, end=76560, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='is', start=76560, end=76880, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='right', start=76880, end=77080, confide ...
#  Utterance(text='World.', start=89420, end=89660, confidence=0.51416016, speaker='C', channel=None, words=[UtteranceWord(text='World.', start=89420, end=89660, confidence=0.51416016, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text="Okay. Back in the day, like, you would basically just show up, take the SAT and, like, hope it went well and maybe take it a second time. And that was kind of it. And there wasn't a ton of, like, prep. You might get a book, maybe. In fact, actually, I do think I did get to take a class, and I was hoping I would really improve. And I got basically the exact same score. It was kind of that. And I think in some ways, a lot hasn't changed from when I was taking the SAT back in 1993 to now with regard to how people think about approaching the sat. What do you think is, like, the way kids generally approach the sat?", start=89900, end=128710, confidence=0.9788937, speaker='A', channel=None, words=[UtteranceWord(text='Okay.', start=89900, end=90460, confidence=0.90022784, speaker='A', channel=None), UtteranceWord(text='Back', start=90620, end=90940, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='in', start=90940, end=91140, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='the', start=91140, end=91300, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='day,', start=91300, end=91580, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='like,', start=91900, end=92220, confidence=0.6508789, speaker='A', channel=None), UtteranceWord(text='you', start=92220, end=92420, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='would', start=92420, end=92580, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='basically', start=92580, end=93060, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='just', start=93060, end=93300, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='show', start=93300, end=93500, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='up,', start=93500, end=93820, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='take', start=93900, end=94180, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='the', start=94180, end=94340, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='SAT', start=94340, end=94900, confidence=0.9824219, speaker='A', channel=None), UtteranceWord(text='and,', start=94900, end=95180, confidence=0.99609375, speaker='A', channel=None), UtteranceWord(text='like,', start=95180, end=95500, confidence=0.7548828, speaker='A', channel=None), UtteranceWord(text='hope', start=96060, end=96340, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='it', start=96340, end=96500, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='went', start=96500, end=96700, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='well', start=96700, end=97020, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='and', start=97020, end=97300, confidence=0.9941406, speaker='A', channel=None), UtteranceWord(text='maybe', start=97300, end=97580, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='take', start=97580, end=97780, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='it', start=97780, end=97940, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='a', start=97940, end=98100, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='second', start=98100, end=98380, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='time.', start=98460, end=98780, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='And', start=98780, end=99060, confidence=0.99658203, speaker='A', channel=None), UtteranceWord(text='that', start=99060, end=99300, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='was', start=99300, end=99460, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='kind', start=99460, end=99620, confidence=0.99121094, speaker='A', channel=None), UtteranceWord(text='of', start=99620, end=99740, confidence=0.8144531, speaker='A', channel=None), Utteranc ...
#  Utterance(text="I mean, I think it really depends, but the way we're always taught here at Alpha is the SAT could be about anything. It's just chance that it's about reading, writing and math. It's not this IQ test where it's like, you have to be math and reading smart to get a good score. It's like, it could have been about, you know, interior design. You know, it's Just trying to prove to colleges that you can study for a test and you can perform under pressure. That's what you're trying to show to colleges, not anything else. It's not an IQ test, but I think a lot of students think that it is. And I think that a lot of them, if they take a practice test and they don't automatically get a 1500, they just grip themselves, okay, I'm not that kind of student. I guess, you know, test optional was a thing for a while, but now with schools reimbursement coming back, it's becoming mandatory again. I think that students are become resigned very easily and. But I think that there's so many resources now, like on YouTube, you know, there's endless SAT channels. I know a lot of students actually created SAT channels like that. That's like a huge thing, is that if you can score above a 1550, you're. You're considered an SAT expert.", start=128790, end=185710, confidence=0.9797898, speaker='C', channel=None, words=[UtteranceWord(text='I', start=128790, end=129030, confidence=0.9667969, speaker='C', channel=None), UtteranceWord(text='mean,', start=129030, end=129150, confidence=0.9526367, speaker='C', channel=None), UtteranceWord(text='I', start=129150, end=129270, confidence=0.99853516, speaker='C', channel=None), UtteranceWord(text='think', start=129270, end=129350, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='it', start=129350, end=129470, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='really', start=129470, end=129630, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='depends,', start=129630, end=129990, confidence=0.9663086, speaker='C', channel=None), UtteranceWord(text='but', start=129990, end=130310, confidence=0.9770508, speaker='C', channel=None), UtteranceWord(text='the', start=131030, end=131310, confidence=0.99853516, speaker='C', channel=None), UtteranceWord(text='way', start=131310, end=131470, confidence=1.0, speaker='C', channel=None), UtteranceWord(text="we're", start=131470, end=131670, confidence=0.99820966, speaker='C', channel=None), UtteranceWord(text='always', start=131670, end=131790, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='taught', start=131790, end=131990, confidence=0.99869794, speaker='C', channel=None), UtteranceWord(text='here', start=131990, end=132110, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='at', start=132110, end=132230, confidence=0.9946289, speaker='C', channel=None), UtteranceWord(text='Alpha', start=132230, end=132590, confidence=0.99593097, speaker='C', channel=None), UtteranceWord(text='is', start=132590, end=132870, confidence=0.9980469, speaker='C', channel=None), UtteranceWord(text='the', start=132870, end=133150, confidence=0.99853516, speaker='C', channel=None), UtteranceWord(text='SAT', start=133150, end=133550, confidence=0.99780273, speaker='C', channel=None), UtteranceWord(text='could', start=133550, end=133710, confidence=0.99316406, speaker='C', channel=None), UtteranceWord(text='be', start=133710, end=133830, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='about', start=133830, end=133990, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='anything.', start=133990, end=134390, confidence=0.99975586, speaker='C', channel=None), UtteranceWord(text="It's", start=134390, end=134710, confidence=0.9996745, speaker='C', channel=None), UtteranceWord(text='just', start=134710, end=134870, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='chance', start=134870, end=135150, confidence=0.9995117, speaker='C', channel=Non ...
#  Utterance(text="And for those who are maybe kids are younger and it's been a little while since you yourself was taking the SAT. The. The max score is 1600. It's made up of two components. There's basically the reading writing portion and then the math portion. You can get an ultimate score of 800 in each of those to make up the perfect 1600. You know, I will say Elle's older.", start=185710, end=207650, confidence=0.9845547, speaker='A', channel=None, words=[UtteranceWord(text='And', start=185710, end=185910, confidence=0.97021484, speaker='A', channel=None), UtteranceWord(text='for', start=185910, end=186070, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='those', start=186070, end=186270, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='who', start=186270, end=186510, confidence=0.9946289, speaker='A', channel=None), UtteranceWord(text='are', start=186510, end=186750, confidence=0.9785156, speaker='A', channel=None), UtteranceWord(text='maybe', start=186750, end=187070, confidence=0.9460449, speaker='A', channel=None), UtteranceWord(text='kids', start=187070, end=187350, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='are', start=187350, end=187510, confidence=0.9736328, speaker='A', channel=None), UtteranceWord(text='younger', start=187510, end=187830, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='and', start=187830, end=187990, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text="it's", start=187990, end=188190, confidence=0.9996745, speaker='A', channel=None), UtteranceWord(text='been', start=188190, end=188310, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='a', start=188310, end=188430, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='little', start=188430, end=188550, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='while', start=188550, end=188750, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='since', start=188750, end=189030, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='you', start=189030, end=189390, confidence=0.9941406, speaker='A', channel=None), UtteranceWord(text='yourself', start=189470, end=189950, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='was', start=189950, end=190150, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='taking', start=190150, end=190310, confidence=0.9892578, speaker='A', channel=None), UtteranceWord(text='the', start=190310, end=190430, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text='SAT.', start=190430, end=190870, confidence=0.9526367, speaker='A', channel=None), UtteranceWord(text='The.', start=190870, end=191230, confidence=0.7055664, speaker='A', channel=None), UtteranceWord(text='The', start=191230, end=191510, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='max', start=191510, end=191790, confidence=0.99560547, speaker='A', channel=None), UtteranceWord(text='score', start=191790, end=192070, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='is', start=192070, end=192270, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='1600.', start=192270, end=192990, confidence=0.99414, speaker='A', channel=None), UtteranceWord(text="It's", start=193070, end=193390, confidence=0.99869794, speaker='A', channel=None), UtteranceWord(text='made', start=193390, end=193510, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='up', start=193510, end=193630, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='of', start=193630, end=193790, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='two', start=193790, end=194030, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='components.', start=194030, end=194670, confidence=0.96203613, speaker='A', channel=None), UtteranceWord(text="There's", start=195150, end=195710, confidence=0.973 ...
#  Utterance(text='Sister got a perfect 1600.', start=207650, end=209970, confidence=0.9968098, speaker='C', channel=None, words=[UtteranceWord(text='Sister', start=207650, end=208050, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='got', start=208450, end=208730, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='a', start=208730, end=208890, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='perfect', start=208890, end=209250, confidence=0.9913737, speaker='C', channel=None), UtteranceWord(text='1600.', start=209250, end=209970, confidence=0.99414, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text="Set the bar pretty high. She got a perfect 1600 a couple years ago when she was doing the college application process. So I will say Alpha students have definitely been shown like, hey, it's possible you can do this. And I want to read a tweet before we get into a little bit more detail on this. This actually came from our principal. Our Alpha principal put this tweet out the other day, and here's what he said. He said SAT scores were released today. Three girl in my Alpha high group were described by their parents as not math science girls. They've been focused on other pursuits. Launching a Broadway musical, competing for Miss Teen USA, building millions of TikTok followers, and becoming a nationally recognized teen dating expert. Their SAT math scores. Girl 179 0.", start=210050, end=258524, confidence=0.98265874, speaker='A', channel=None, words=[UtteranceWord(text='Set', start=210050, end=210330, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='the', start=210330, end=210490, confidence=0.99609375, speaker='A', channel=None), UtteranceWord(text='bar', start=210490, end=210770, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='pretty', start=210770, end=211130, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='high.', start=211130, end=211370, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='She', start=211370, end=211610, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='got', start=211610, end=211770, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='a', start=211770, end=211890, confidence=0.99560547, speaker='A', channel=None), UtteranceWord(text='perfect', start=211890, end=212130, confidence=0.9998372, speaker='A', channel=None), UtteranceWord(text='1600', start=212130, end=212850, confidence=0.99658, speaker='A', channel=None), UtteranceWord(text='a', start=212850, end=213090, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='couple', start=213090, end=213330, confidence=0.9992676, speaker='A', channel=None), UtteranceWord(text='years', start=213330, end=213530, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='ago', start=213530, end=213730, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='when', start=213730, end=214010, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='she', start=214010, end=214210, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='was', start=214210, end=214290, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='doing', start=214290, end=214410, confidence=0.99316406, speaker='A', channel=None), UtteranceWord(text='the', start=214410, end=214570, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='college', start=214570, end=214850, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='application', start=214850, end=215370, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='process.', start=215370, end=215730, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='So', start=215890, end=216290, confidence=0.9707031, speaker='A', channel=None), UtteranceWord(text='I', start=216610, end=216890, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='will', start=216890, end=217050, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='say', start=217050, end=217210, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='Alpha', start=217210, end=217610, confidence=0.9983724, speaker='A', channel=None), UtteranceWord(text='students', start=217610, end=217850, confidence=0.9951172, speaker='A', channel=None), UtteranceWord(text='have', start=217850, end=218130, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='definitely', start=218130, end=218690, confidence=0.96606445, speaker='A', channel=None), UtteranceWord(text=' ...
#  Utterance(text='Girl 2790379 0.', start=258719, end=261550, confidence=0.86561, speaker='C', channel=None, words=[UtteranceWord(text='Girl', start=258719, end=259500, confidence=0.86561, speaker='C', channel=None), UtteranceWord(text='2790379', start=259695, end=260476, confidence=0.86561, speaker='C', channel=None), UtteranceWord(text='0.', start=260671, end=261550, confidence=0.86561, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text="Place kids in the right environment and they'll shatter every ceiling you thought existed. So let's talk a little bit about that whole tweet. First of all, what's up with everyone scoring the same on math?", start=262030, end=274970, confidence=0.99746364, speaker='A', channel=None, words=[UtteranceWord(text='Place', start=262030, end=262390, confidence=0.99316406, speaker='A', channel=None), UtteranceWord(text='kids', start=262390, end=262750, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='in', start=262750, end=262950, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='the', start=262950, end=263110, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='right', start=263110, end=263310, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='environment', start=263310, end=263630, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='and', start=263790, end=264110, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text="they'll", start=264110, end=264590, confidence=0.96940106, speaker='A', channel=None), UtteranceWord(text='shatter', start=264590, end=265070, confidence=0.9824219, speaker='A', channel=None), UtteranceWord(text='every', start=265310, end=265710, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='ceiling', start=265710, end=266430, confidence=0.9794922, speaker='A', channel=None), UtteranceWord(text='you', start=266510, end=266910, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='thought', start=266910, end=267310, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='existed.', start=267310, end=267950, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='So', start=268650, end=268890, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text="let's", start=268970, end=269410, confidence=0.9998372, speaker='A', channel=None), UtteranceWord(text='talk', start=269410, end=269610, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='a', start=269610, end=269770, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='little', start=269770, end=269890, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='bit', start=269890, end=270090, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='about', start=270090, end=270410, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='that', start=270570, end=270930, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='whole', start=270930, end=271290, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='tweet.', start=271290, end=271730, confidence=0.9972331, speaker='A', channel=None), UtteranceWord(text='First', start=271730, end=271970, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='of', start=271970, end=272130, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='all,', start=272130, end=272410, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text="what's", start=272570, end=272970, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='up', start=272970, end=273090, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='with', start=273090, end=273290, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='everyone', start=273290, end=273570, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='scoring', start=273570, end=274050, confidence=0.9998372, speaker='A', channel=None), UtteranceWord(text='the', start=274050, end=274210, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='same', start=274210, end=274410, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='on', start=274410, end=274610, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='math?', start=274610, end=274970, confidence=0.9987793, speaker='A', channel=None)], translated_texts=None ...
#  Utterance(text="That's weird. It's actually crazy. We all, like, opened them on the same day, and we were all like, oh, my gosh. We were all so excited. And I was like, what'd you get? They're like, 790. I was like, what'd you get? She's like, 790. I'm like, and then we actually have a guy friend who got a 790 as well. And we were like, literally. What just happened? It was the craziest day ever.", start=275130, end=291810, confidence=0.9766386, speaker='C', channel=None, words=[UtteranceWord(text="That's", start=275130, end=275450, confidence=0.96761066, speaker='C', channel=None), UtteranceWord(text='weird.', start=275450, end=275650, confidence=0.9972331, speaker='C', channel=None), UtteranceWord(text="It's", start=275650, end=275770, confidence=0.8886719, speaker='C', channel=None), UtteranceWord(text='actually', start=275770, end=275970, confidence=0.93066406, speaker='C', channel=None), UtteranceWord(text='crazy.', start=275970, end=276410, confidence=0.99104816, speaker='C', channel=None), UtteranceWord(text='We', start=277530, end=277810, confidence=0.99609375, speaker='C', channel=None), UtteranceWord(text='all,', start=277810, end=277970, confidence=0.9970703, speaker='C', channel=None), UtteranceWord(text='like,', start=277970, end=278130, confidence=0.73095703, speaker='C', channel=None), UtteranceWord(text='opened', start=278130, end=278490, confidence=0.99731445, speaker='C', channel=None), UtteranceWord(text='them', start=278490, end=278610, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='on', start=278610, end=278730, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='the', start=278730, end=278810, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='same', start=278810, end=278930, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='day,', start=278930, end=279090, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='and', start=279090, end=279250, confidence=0.9980469, speaker='C', channel=None), UtteranceWord(text='we', start=279250, end=279370, confidence=0.9975586, speaker='C', channel=None), UtteranceWord(text='were', start=279370, end=279450, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='all', start=279450, end=279530, confidence=0.9951172, speaker='C', channel=None), UtteranceWord(text='like,', start=279530, end=279690, confidence=0.99609375, speaker='C', channel=None), UtteranceWord(text='oh,', start=279690, end=279930, confidence=0.9938965, speaker='C', channel=None), UtteranceWord(text='my', start=279930, end=280050, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='gosh.', start=280050, end=280330, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='We', start=280330, end=280490, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='were', start=280490, end=280570, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='all', start=280570, end=280690, confidence=0.99121094, speaker='C', channel=None), UtteranceWord(text='so', start=280690, end=280850, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='excited.', start=280850, end=281170, confidence=0.9992676, speaker='C', channel=None), UtteranceWord(text='And', start=281170, end=281370, confidence=0.97753906, speaker='C', channel=None), UtteranceWord(text='I', start=281370, end=281450, confidence=0.99365234, speaker='C', channel=None), UtteranceWord(text='was', start=281450, end=281530, confidence=0.99609375, speaker='C', channel=None), UtteranceWord(text='like,', start=281530, end=281650, confidence=0.9897461, speaker='C', channel=None), UtteranceWord(text="what'd", start=281650, end=281890, confidence=0.9703776, speaker='C', channel=None), UtteranceWord(text='you', start=281890, end=282010, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='get?', start=282010, end=282210, confidence=1.0, speaker='C', channel=None), UtteranceWord(text="They ...
#  Utterance(text='So basically a 790 out of 800 on math means you probably miss one question. It can depend a little bit. The SAT scores, you know, vary by the test, but basically you miss one question and you do this. But what I like about this point was first of all, the idea of not math science girls. Like, have you ever considered yourself to be a math science type of person?', start=291810, end=312470, confidence=0.9825688, speaker='A', channel=None, words=[UtteranceWord(text='So', start=291810, end=292090, confidence=0.9814453, speaker='A', channel=None), UtteranceWord(text='basically', start=292090, end=292450, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='a', start=292450, end=292730, confidence=0.9902344, speaker='A', channel=None), UtteranceWord(text='790', start=292730, end=293290, confidence=0.83805, speaker='A', channel=None), UtteranceWord(text='out', start=293290, end=293570, confidence=0.98535156, speaker='A', channel=None), UtteranceWord(text='of', start=293570, end=293730, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='800', start=293730, end=294090, confidence=0.99976, speaker='A', channel=None), UtteranceWord(text='on', start=294090, end=294290, confidence=0.99609375, speaker='A', channel=None), UtteranceWord(text='math', start=294290, end=294530, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='means', start=294530, end=294690, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='you', start=294690, end=294850, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='probably', start=294850, end=295170, confidence=0.99641925, speaker='A', channel=None), UtteranceWord(text='miss', start=295170, end=295530, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='one', start=295530, end=295890, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='question.', start=295890, end=296250, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='It', start=296890, end=297130, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='can', start=297130, end=297210, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='depend', start=297210, end=297530, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='a', start=297530, end=297690, confidence=0.9946289, speaker='A', channel=None), UtteranceWord(text='little', start=297690, end=297770, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='bit.', start=297770, end=297970, confidence=0.9604492, speaker='A', channel=None), UtteranceWord(text='The', start=297970, end=298330, confidence=0.859375, speaker='A', channel=None), UtteranceWord(text='SAT', start=298490, end=299130, confidence=0.9194336, speaker='A', channel=None), UtteranceWord(text='scores,', start=299130, end=299610, confidence=0.9842122, speaker='A', channel=None), UtteranceWord(text='you', start=299610, end=299770, confidence=0.7529297, speaker='A', channel=None), UtteranceWord(text='know,', start=299770, end=299920, confidence=0.99560547, speaker='A', channel=None), UtteranceWord(text='vary', start=300150, end=300470, confidence=0.8474121, speaker='A', channel=None), UtteranceWord(text='by', start=300550, end=300830, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='the', start=300830, end=300990, confidence=0.9736328, speaker='A', channel=None), UtteranceWord(text='test,', start=300990, end=301230, confidence=0.98828125, speaker='A', channel=None), UtteranceWord(text='but', start=301230, end=301470, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text='basically', start=301470, end=301790, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='you', start=301790, end=301950, confidence=0.9921875, speaker='A', channel=None), UtteranceWord(text='miss', start=301950, end=302150, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='one', start=302150, end=3023 ...
#  Utterance(text="I mean, I feel like someone could have won a lot of money off of me if they had bet me whether I was going to get above a 750 even, you know, or 720 even, you know, when I was even very young. Up until just a few months ago or, you know, since Alpha kind of changed my mindset around math, I just really didn't think I was a math science girl. I mean, look at my sister, 1600, she's a math major at Stanford. There was, we're really close and there's not a ton of competition. But it is kind of where you're like, you place yourself in a different group. It's like, okay, I'm going to excel socially versus in this realm where it's just impossible. It's not like she's a math girl, she's a math and English girl. So I was like, okay, I'm just going to put myself in this other group. But I think with Alpha's mindset around SAT and just education in general, where it's not an IQ test, there's, you know, you can be a top performing student no matter what. It's just effort. That's something. Something. We always, our guides always make sure that we can articulate the number of hours until we get our dream score. So it's not number of IQ points until we get our dream score. It's always like, okay, how many hours do you have until you get a 1500? For students who are aiming for that, it's like 15 hours in math, five hours in, you know, English.", start=312790, end=376890, confidence=0.97517735, speaker='C', channel=None, words=[UtteranceWord(text='I', start=312790, end=313070, confidence=0.9580078, speaker='C', channel=None), UtteranceWord(text='mean,', start=313070, end=313310, confidence=0.99853516, speaker='C', channel=None), UtteranceWord(text='I', start=313310, end=313550, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='feel', start=313550, end=313750, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='like', start=313750, end=314070, confidence=0.99658203, speaker='C', channel=None), UtteranceWord(text='someone', start=314230, end=314590, confidence=0.99902344, speaker='C', channel=None), UtteranceWord(text='could', start=314590, end=314830, confidence=0.9980469, speaker='C', channel=None), UtteranceWord(text='have', start=314830, end=315110, confidence=0.93652344, speaker='C', channel=None), UtteranceWord(text='won', start=315270, end=315590, confidence=0.9970703, speaker='C', channel=None), UtteranceWord(text='a', start=315590, end=315750, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='lot', start=315750, end=315909, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='of', start=315909, end=316150, confidence=0.99609375, speaker='C', channel=None), UtteranceWord(text='money', start=316150, end=316390, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='off', start=316390, end=316590, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='of', start=316590, end=316750, confidence=0.9951172, speaker='C', channel=None), UtteranceWord(text='me', start=316750, end=316910, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='if', start=316910, end=317030, confidence=1.0, speaker='C', channel=None), UtteranceWord(text='they', start=317030, end=317150, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='had', start=317150, end=317270, confidence=0.95703125, speaker='C', channel=None), UtteranceWord(text='bet', start=317270, end=317430, confidence=0.9550781, speaker='C', channel=None), UtteranceWord(text='me', start=317430, end=317630, confidence=0.99316406, speaker='C', channel=None), UtteranceWord(text='whether', start=317630, end=317830, confidence=0.9980469, speaker='C', channel=None), UtteranceWord(text='I', start=317830, end=317990, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='was', start=317990, end=318110, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='going', start=318110, end=318230, confidence=0.54589844, speaker='C', channel=None), Utter ...
# ...
#  Utterance(text='And the questions are designed to trick you.', start=825380, end=826860, confidence=0.9623718, speaker='C', channel=None, words=[UtteranceWord(text='And', start=825380, end=825580, confidence=0.85498047, speaker='C', channel=None), UtteranceWord(text='the', start=825580, end=825660, confidence=0.9770508, speaker='C', channel=None), UtteranceWord(text='questions', start=825660, end=825940, confidence=0.8894043, speaker='C', channel=None), UtteranceWord(text='are', start=825940, end=826100, confidence=0.98095703, speaker='C', channel=None), UtteranceWord(text='designed', start=826100, end=826420, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='to', start=826420, end=826540, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='trick', start=826540, end=826700, confidence=0.9995117, speaker='C', channel=None), UtteranceWord(text='you.', start=826700, end=826860, confidence=0.9980469, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text='You.', start=826860, end=827100, confidence=0.91503906, speaker='A', channel=None, words=[UtteranceWord(text='You.', start=826860, end=827100, confidence=0.91503906, speaker='A', channel=None)], translated_texts=None),
#  Utterance(text="You can't possibly.", start=827100, end=828060, confidence=0.99018013, speaker='C', channel=None, words=[UtteranceWord(text='You', start=827100, end=827300, confidence=0.9946289, speaker='C', channel=None), UtteranceWord(text="can't", start=827300, end=827580, confidence=0.99886066, speaker='C', channel=None), UtteranceWord(text='possibly.', start=827580, end=828060, confidence=0.9770508, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text="So you get overloaded. And it's not. Whereas when you actually have fast math, then that is not something that your brain has to think about. And it frees up your cognitive load to be able to say, let's go focus on the hard part of this problem and not get tripped up on the easy part of the problem. And so that's one of the things that I think commonly happens. So this student, did, you know, a couple weeks worth of lessons on fast math that allowed her to go back in and in a time crunch, quickly go through. Now you know fast math for some people. Well, first of all, you know what's interesting, Elle, is so many schools aren't having kids learn their fast math. What? Yeah. Did you know that, like, multiplication tables are not required to be memorized anymore?", start=828220, end=871930, confidence=0.98710096, speaker='A', channel=None, words=[UtteranceWord(text='So', start=828220, end=828500, confidence=0.9838867, speaker='A', channel=None), UtteranceWord(text='you', start=828500, end=828660, confidence=0.99658203, speaker='A', channel=None), UtteranceWord(text='get', start=828660, end=828820, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='overloaded.', start=828820, end=829540, confidence=0.9986572, speaker='A', channel=None), UtteranceWord(text='And', start=829540, end=829740, confidence=0.9926758, speaker='A', channel=None), UtteranceWord(text="it's", start=829740, end=829900, confidence=0.9983724, speaker='A', channel=None), UtteranceWord(text='not.', start=829900, end=830140, confidence=0.9921875, speaker='A', channel=None), UtteranceWord(text='Whereas', start=830140, end=830700, confidence=0.99438477, speaker='A', channel=None), UtteranceWord(text='when', start=831080, end=831240, confidence=0.98095703, speaker='A', channel=None), UtteranceWord(text='you', start=831240, end=831440, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='actually', start=831440, end=831680, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='have', start=831680, end=831960, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='fast', start=831960, end=832280, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='math,', start=832280, end=832600, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='then', start=832600, end=832840, confidence=0.9921875, speaker='A', channel=None), UtteranceWord(text='that', start=832840, end=833080, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='is', start=833080, end=833280, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='not', start=833280, end=833480, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='something', start=833480, end=833720, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='that', start=833720, end=833880, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='your', start=833880, end=834000, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='brain', start=834000, end=834320, confidence=0.998291, speaker='A', channel=None), UtteranceWord(text='has', start=834320, end=834560, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='to', start=834560, end=834720, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='think', start=834720, end=834840, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='about.', start=834840, end=835080, confidence=0.90478516, speaker='A', channel=None), UtteranceWord(text='And', start=835080, end=835360, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text='it', start=835360, end=835600, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='frees', start=835600, end=836000, confidence=0.99975586, speaker='A', channel=None), UtteranceWord(text='up', start=836000, end=836280, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='your', start=836280, end=836600, conf ...
#  Utterance(text='Not like the sheets and the time test?', start=871930, end=873249, confidence=0.7741699, speaker='C', channel=None, words=[UtteranceWord(text='Not', start=871930, end=872010, confidence=0.6245117, speaker='C', channel=None), UtteranceWord(text='like', start=872010, end=872250, confidence=0.44458008, speaker='C', channel=None), UtteranceWord(text='the', start=872250, end=872490, confidence=0.8925781, speaker='C', channel=None), UtteranceWord(text='sheets', start=872490, end=872650, confidence=0.9812012, speaker='C', channel=None), UtteranceWord(text='and', start=872650, end=872730, confidence=0.82421875, speaker='C', channel=None), UtteranceWord(text='the', start=872730, end=872850, confidence=0.5629883, speaker='C', channel=None), UtteranceWord(text='time', start=872850, end=873010, confidence=0.9897461, speaker='C', channel=None), UtteranceWord(text='test?', start=873010, end=873249, confidence=0.87353516, speaker='C', channel=None)], translated_texts=None),
#  Utterance(text="They're not. They don't. There's a lot of de emphasis on that. And so you do kind of. You can see why people are struggling with these types of things.", start=873249, end=882570, confidence=0.9758138, speaker='A', channel=None, words=[UtteranceWord(text="They're", start=873249, end=873530, confidence=0.93310547, speaker='A', channel=None), UtteranceWord(text='not.', start=873530, end=873650, confidence=0.99658203, speaker='A', channel=None), UtteranceWord(text='They', start=873650, end=873810, confidence=0.78027344, speaker='A', channel=None), UtteranceWord(text="don't.", start=873810, end=874170, confidence=0.99641925, speaker='A', channel=None), UtteranceWord(text="There's", start=874250, end=874690, confidence=0.9977214, speaker='A', channel=None), UtteranceWord(text='a', start=874690, end=874850, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='lot', start=874850, end=875010, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='of', start=875010, end=875290, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='de', start=875450, end=875730, confidence=0.9897461, speaker='A', channel=None), UtteranceWord(text='emphasis', start=875730, end=876290, confidence=0.93115234, speaker='A', channel=None), UtteranceWord(text='on', start=876290, end=876450, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='that.', start=876450, end=876730, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='And', start=877050, end=877450, confidence=0.73095703, speaker='A', channel=None), UtteranceWord(text='so', start=877770, end=878050, confidence=0.99853516, speaker='A', channel=None), UtteranceWord(text='you', start=878050, end=878250, confidence=0.9770508, speaker='A', channel=None), UtteranceWord(text='do', start=878250, end=878490, confidence=0.99609375, speaker='A', channel=None), UtteranceWord(text='kind', start=878490, end=878690, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='of.', start=878690, end=878970, confidence=0.9980469, speaker='A', channel=None), UtteranceWord(text='You', start=879610, end=879890, confidence=0.98876953, speaker='A', channel=None), UtteranceWord(text='can', start=879890, end=880090, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='see', start=880090, end=880330, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='why', start=880330, end=880610, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='people', start=880610, end=880890, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='are', start=880890, end=881170, confidence=0.9995117, speaker='A', channel=None), UtteranceWord(text='struggling', start=881170, end=881610, confidence=1.0, speaker='A', channel=None), UtteranceWord(text='with', start=881610, end=881810, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='these', start=881810, end=881970, confidence=0.99902344, speaker='A', channel=None), UtteranceWord(text='types', start=881970, end=882210, confidence=0.9736328, speaker='A', channel=None), UtteranceWord(text='of', start=882210, end=882330, confidence=0.9970703, speaker='A', channel=None), UtteranceWord(text='things.', start=882330, end=882570, confidence=0.9980469, speaker='A', channel=None)], translated_texts=None),
#  Utterance(text="That wraps up part one of this episode, but don't worry, there's a part two coming soon. Thanks for listening to Mackenzie Price and the Future of Education podcast. If you haven't hit that subscribe button, now is the time to do it. So you can stay up to date on all our episodes. You can connect with MacKenzie on social media and be part of our daily conversation over on Instagram @FutureOfEducation. For more info about the show and our guests, you can always visit futureofeducationpod.com lastly, if you're loving what you're learning. Please leave a review wherever you listen to podcasts. We'll be back in your feed soon, but until then, remember, kids are limitless, and it's our job to unlock their potential.", start=884450, end=921330, confidence=0.9833682, speaker='B', channel=None, words=[UtteranceWord(text='That', start=884450, end=884570, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='wraps', start=884570, end=884850, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='up', start=884850, end=885050, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='part', start=885050, end=885250, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='one', start=885250, end=885410, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='of', start=885410, end=885530, confidence=0.9975586, speaker='B', channel=None), UtteranceWord(text='this', start=885530, end=885690, confidence=0.99609375, speaker='B', channel=None), UtteranceWord(text='episode,', start=885690, end=886050, confidence=0.94433594, speaker='B', channel=None), UtteranceWord(text='but', start=886050, end=886290, confidence=0.9975586, speaker='B', channel=None), UtteranceWord(text="don't", start=886290, end=886530, confidence=0.9996745, speaker='B', channel=None), UtteranceWord(text='worry,', start=886530, end=886770, confidence=0.9941406, speaker='B', channel=None), UtteranceWord(text="there's", start=886770, end=887090, confidence=0.99527997, speaker='B', channel=None), UtteranceWord(text='a', start=887090, end=887170, confidence=0.98583984, speaker='B', channel=None), UtteranceWord(text='part', start=887170, end=887330, confidence=0.9980469, speaker='B', channel=None), UtteranceWord(text='two', start=887330, end=887530, confidence=0.99658203, speaker='B', channel=None), UtteranceWord(text='coming', start=887530, end=887770, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='soon.', start=887770, end=888130, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='Thanks', start=888290, end=888650, confidence=0.9992676, speaker='B', channel=None), UtteranceWord(text='for', start=888650, end=888810, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='listening', start=888810, end=889130, confidence=0.8720703, speaker='B', channel=None), UtteranceWord(text='to', start=889130, end=889290, confidence=0.9980469, speaker='B', channel=None), UtteranceWord(text='Mackenzie', start=889290, end=889850, confidence=0.9707845, speaker='B', channel=None), UtteranceWord(text='Price', start=889850, end=890130, confidence=0.97509766, speaker='B', channel=None), UtteranceWord(text='and', start=890130, end=890410, confidence=0.9921875, speaker='B', channel=None), UtteranceWord(text='the', start=890410, end=890570, confidence=0.9975586, speaker='B', channel=None), UtteranceWord(text='Future', start=890570, end=890810, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='of', start=890810, end=891090, confidence=0.9995117, speaker='B', channel=None), UtteranceWord(text='Education', start=891090, end=891410, confidence=1.0, speaker='B', channel=None), UtteranceWord(text='podcast.', start=891650, end=892210, confidence=0.9992676, speaker='B', channel=None), UtteranceWord(text='If', start=892210, end=892410, confidence=0.99902344, speaker='B', channel=None), UtteranceWord(text='you', start=892410, end=892530, confidence=0.9995 ...

# %%
import os
import re
import json
import feedparser

def sanitize_filename(filename):
    clean_name = re.sub(r'[\\/*?:"<>|]', "", filename)
    clean_name = "".join(ch for ch in clean_name if ord(ch) >= 32)
    return clean_name.strip()

RSS_FEED_URL = "https://rss.art19.com/future-of-education"
METADATA_DIR = "test_metadata_output"

# Create output directory
if not os.path.exists(METADATA_DIR):
    os.makedirs(METADATA_DIR)
    print(f"Created directory: {METADATA_DIR}")

print(f"Parsing RSS feed: {RSS_FEED_URL}")
feed = feedparser.parse(RSS_FEED_URL)
print(f"Found {len(feed.entries)} episodes.\n")

# Process the first 5 episodes for testing
for entry in feed.entries[:5]:
    title = entry.get('title', 'Unknown Title')
    clean_title = sanitize_filename(title)
    
    # Extract specific fields requested
    metadata = {
        "title": title,
        "summary": entry.get("summary"),
        "published": entry.get("published"),
        # Extract href from image dict if available
        "image": entry.get("image", {}).get("href") if isinstance(entry.get("image"), dict) else entry.get("image"),
        "links": entry.get("links", []),
    }

    # Handle tags (list of objects -> list of strings)
    if "tags" in entry:
        metadata["tags"] = [t.get("term") for t in entry.tags]
    
    # Handle content (list of objects -> list of values)
    if "content" in entry:
        metadata["content"] = [c.get("value") for c in entry.content]
        
    # Additional useful iTunes fields
    if "itunes_episode" in entry:
        metadata["itunes_episode"] = entry.get("itunes_episode")
    if "itunes_season" in entry:
        metadata["itunes_season"] = entry.get("itunes_season")
    if "itunes_duration" in entry:
        metadata["itunes_duration"] = entry.get("itunes_duration")

    # Save to JSON
    filename = f"{clean_title}.json"
    filepath = os.path.join(METADATA_DIR, filename)
    
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(metadata, f, indent=2, ensure_ascii=False)
    
    print(f"Saved metadata for: {title}")

print(f"\nCheck the '{METADATA_DIR}' directory for results.")
# Out:
# Parsing RSS feed: https://rss.art19.com/future-of-education
# Found 259 episodes.
#
# Saved metadata for: S2E283: The Truth About the SAT: Mindset Matters More Than IQ (Part 2)
# Saved metadata for: S2E282: The SAT Isn’t About Intelligence… Here’s How to Win (Part 1)
# Saved metadata for: S2E281: (Part 2) The Skill Kids Need but Rarely Learn… Feedback 101 with Guide Emily
# Saved metadata for: S2E280: Building Capable Kids Through The Feedback Formula - With Guide Emily (Part 1)
# Saved metadata for: S2E279: Does Alpha Go Too Far? We Tackle Your Harshest Criticisms (Part 2)
#
# Check the 'test_metadata_output' directory for results.
